# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 6)

downloads = [
    86181,
    289034,
    369114,
    338312,
    332630,
    128642,
    380150,
    373622,
    346472,
    434069,
    486342,
    551037,
    648527,
    665698,
    793294,
    700246,
    683112,
    626382,
    535059,
    520109,
    814607,
    804750,
    795325,
    913798,
    1014577,
    1017563,
    1060112,
    980532,
    1276799,
    987399,
]

plt.bar(range(len(downloads)), downloads)
plt.title('Downloads by month')
plt.xticks(range(len(downloads)), 'NDJFMAMJJASONDJFMAMJJASONDJFMA')

plt.show()

# %%
time_saved = [
    
]

colors = ['blue']*9 + ['red']*3
plt.bar(range(len(time_saved)), time_saved.values(), color=colors)
plt.title('Time saved by month')
plt.xticks(range(len(time_saved)), list(downloads.keys()))

plt.show()

# %%
os = {
    'Raspbian': 2797487,
    'Debian': 97945,
    'Ubuntu': 40534,
    'other': 8542,
}

plt.pie(os.values(), labels=os.keys())
plt.title('Operating system usage')

plt.show()

# %%
arch = {
    'armv7l': 2641465,
    'armv6l': 239004,
    'x86_64': 50456,
}

plt.pie(arch.values(), labels=arch.keys())
plt.title('Architecture usage')

plt.show()

# %%
arch = {
    '3.7': 1843458,
    '3.5': 602827,
    '2.7': 428694,
    '3.6': 239004,
    'others': 13793+5515,
}

plt.pie(arch.values(), labels=arch.keys())
plt.title('Python version usage')

plt.show()
