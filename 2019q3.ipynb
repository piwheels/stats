# %%
import matplotlib.pyplot as plt

# %%
archs = {
    'armv7l': 2158170,
    'armv6l':  196557,
    'x86_64':   51006,
}

arch_pie = plt.pie(archs.values(), labels=archs.keys())
print(archs['armv7l'] / sum(archs.values()))
print(archs['armv6l'] / sum(archs.values()))
print(archs['armv7l'] / sum([archs['armv7l'], archs['armv6l']]))
# Out:
# 0.8970945653570035
# 0.08170358057190885
# 0.9165266292016017

# %%
oss = {
    'raspbian': 2274184,
    'debian': 92020,
    'ubuntu': 37600,
    'other': 8293,
}

os_pie = plt.pie(oss.values(), labels=oss.keys())
oss['raspbian'] / sum(oss.values())
# Out:
# 0.9428244386523428

# %%
py_vers = {
    '3.7': 1350374,
    '3.5': 788191, 
    '2.7': 206259,
    '3.6': 63978,
    '3.4': 5203,
    '3.8': 393,
}

py_ver_pie = plt.pie(py_vers.values(), labels=py_vers.keys())
py_vers['3.5'] / sum(py_vers.values())
# Out:
# 0.32645446194040917

# %%
downloads = {
    'Oct': 551037,
    'Nov': 648527,
    'Dec': 665698,
    'Jan': 793294,
    'Feb': 700246,
    'Mar': 683112,
    'Apr': 626382,
    'May': 535059,
    'Jun': 520109,
    'Jul': 814607,
    'Aug': 804750,
    'Sep': 795325,
}

colors = ['blue'] * 9 + ['red'] * 3
downloads_bar = plt.bar(range(len(downloads)), downloads.values(), tick_label=list(downloads.keys()), color=colors)
plt.title('Downloads by month')
# Out:
# Text(0.5, 1.0, 'Downloads by month')

# %%
time_saved = {
    'Oct': 6 + (2/12),
    'Nov': 6 + (11/12),
    'Dec': 6 + (9/12),
    'Jan': 8 + (4/12),
    'Feb': 8 + (8.5/12),
    'Mar': 8 + (2/12),
    'Apr': 8 + (10.5/12),
    'May': 7 + (11.5/12),
    'Jun': 7 + (9.5/12),
    'Jul': 10 + (9/12),
    'Aug': 7 + (1/12),
    'Sep': 11 + (3/12),
}

colors = ['blue'] * 9 + ['red'] * 3
time_saved_bar = plt.bar(range(len(time_saved)), time_saved.values(), tick_label=list(time_saved.keys()), color=colors)
plt.title('Time saved by month')
plt.ylabel('Years')
# Out:
# Text(0, 0.5, 'Years')
