# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 6)

downloads = {
    'Apr': 626382,
    'May': 535059,
    'Jun': 520109,
    'Jul': 814607,
    'Aug': 804750,
    'Sep': 795325,
    'Oct': 913798,
    'Nov': 1014577,
    'Dec': 1017563,
    'Jan': 1060112,
    'Feb': 980532,
    'Mar': 1276799,
}

colors = ['blue']*9 + ['red']*3
plt.bar(range(len(downloads)), downloads.values(), color=colors)
plt.title('Downloads by month')
plt.xticks(range(len(downloads)), list(downloads.keys()))

plt.savefig('downloads-by-month.png')

plt.show()

# %%
time_saved = {
    'Apr': 76760,
    'May': 68975,
    'Jun': 67406,
    'Jul': 92737,
    'Aug': 60992,
    'Sep': 97272,
    'Oct': 118188,
    'Nov': 153604,
    'Dec': 153948,
    'Jan': 150659,
    'Feb': 169774,
    'Mar': 196052,
}

colors = ['blue']*9 + ['red']*3
plt.bar(range(len(time_saved)), time_saved.values(), color=colors)
plt.title('Time saved by month')
plt.xticks(range(len(time_saved)), list(downloads.keys()))

plt.savefig('time-saved-by-month.png')

plt.show()

# %%
os = {
    'Raspbian': 3138831,
    'Debian': 119653,
    'Ubuntu': 43074,
    'other': 13878,
}

plt.pie(os.values(), labels=os.keys())
plt.title('Operating system usage')

plt.savefig('os-usage.png')

plt.show()

# %%
arch = {
    'armv7l': 2641465,
    'armv6l': 239004,
    'x86_64': 50456,
}

plt.pie(arch.values(), labels=arch.keys())
plt.title('Architecture usage')

plt.savefig('arch.png')

plt.show()

# %%
py_vers = {
    '3.7': 2184072,
    '2.7': 648543,
    '3.5': 417064,
    'others': 53+440+2128+27776+37208,
}

plt.pie(py_vers.values(), labels=py_vers.keys())
plt.title('Python version usage')

plt.savefig('py-vers.png')

plt.show()

# %%
data = [
    # 3.7, 3.5, 2.7, others
    [6083, 486890, 118551, 14814],
    [20229, 401528,  99818, 13478],
    [75180, 343379,  86253, 15182],
    [367114, 354708,  73733, 18934],
    [461468, 244323,  73432, 25418],
    [521792, 189160,  59094, 25222],
    [584240, 205026, 101517, 23003],
    [630775, 214699, 143212, 25820],
    [616066, 180382, 179917, 21488],
    [693624, 171488, 173022, 21967],
    [711204, 127105, 122132, 19957],
    [779244, 118471, 353389, 25681],
]

py_vers = ['Python 3.7', 'Python 3.5', 'Python 2.7', 'others']

d = {
    ver: [month[i] / sum(month) for month in data]
    for i, ver in enumerate(py_vers)
}

months = ['Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar']
plt.stackplot(months, d.values(), labels=d.keys())
plt.legend(loc='upper left')

plt.savefig('py-vers-over-time.png')

# %%
downloads = [
    ['1 Jan', 31081],
    ['', 31427],
    ['', 37298],
    ['', 35886],
    ['', 37274],
    ['', 34101],
    ['', 34463],
    ['', 37916],
    ['', 37664],
    ['', 32880],
    ['', 23383],
    ['', 36852],
    ['', 35090],
    ['', 37800],
    ['', 35652],
    ['', 37794],
    ['', 38139],
    ['', 35074],
    ['', 36674],
    ['', 36385],
    ['', 35466],
    ['', 32415],
    ['', 33393],
    ['', 31131],
    ['', 29725],
    ['', 31176],
    ['', 30859],
    ['', 33707],
    ['', 31684],
    ['', 34100],
    ['', 33623],
    ['1 Feb', 34042],
    ['', 33017],
    ['', 32534],
    ['', 33123],
    ['', 33789],
    ['', 34760],
    ['', 32460],
    ['', 29539],
    ['', 32684],
    ['', 33490],
    ['', 34334],
    ['', 32636],
    ['', 33821],
    ['', 31969],
    ['', 31155],
    ['', 31367],
    ['', 36037],
    ['', 37278],
    ['', 36147],
    ['', 29724],
    ['', 33613],
    ['', 32854],
    ['', 34635],
    ['', 36347],
    ['', 35508],
    ['', 37728],
    ['', 37342],
    ['', 35046],
    ['', 33553],
    ['1 Mar', 37797],
    ['', 33968],
    ['', 37895],
    ['', 56225],
    ['', 60324],
    ['', 52879],
    ['', 49400],
    ['', 46151],
    ['', 43381],
    ['', 42099],
    ['', 40480],
    ['', 39363],
    ['', 39565],
    ['', 39948],
    ['', 28047],
    ['', 37672],
    ['', 39007],
    ['', 39530],
    ['', 40177],
    ['', 38818],
    ['', 41392],
    ['', 42728],
    ['', 39855],
    ['', 39378],
    ['', 38309],
    ['', 39251],
    ['', 38958],
    ['', 38823],
    ['', 44016],
    ['', 39888],
]

plt.bar(range(len(downloads)), [d[1] for d in downloads])
plt.title('Downloads by day')
plt.xticks(range(len(downloads)), [d[0] for d in downloads])

plt.savefig('downloads-by-day.png')

plt.show()
