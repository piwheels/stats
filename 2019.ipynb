# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 6)

downloads = {
    'Jan': 793294,
    'Feb': 700246,
    'Mar': 683112,
    'Apr': 626382,
    'May': 535059,
    'Jun': 520109,
    'Jul': 814607,
    'Aug': 804750,
    'Sep': 795325,
    'Oct': 913798,
    'Nov': 1014577,
    'Dec': 1017563,
}

plt.bar(range(len(downloads)), downloads.values())
plt.title('Downloads by month')
plt.xticks(range(len(downloads)), list(downloads.keys()))

plt.show()

# %%
time_saved = {
    'Jan': 72135,
    'Feb': 75145,
    'Mar': 70579,
    'Apr': 76760,
    'May': 68975,
    'Jun': 67406,
    'Jul': 92737,
    'Aug': 60992,
    'Sep': 97272,
    'Oct': 118188,
    'Nov': 153604,
    'Dec': 153948,

}

plt.bar(range(len(time_saved)), time_saved.values())
plt.title('Time saved by month')
plt.xticks(range(len(time_saved)), list(downloads.keys()))

plt.show()

# %%
data = [
    [5477, 728555,  46704, 12505],
    [6739, 638689,  43896, 10766],
    [14361, 607736,  47453, 13436],
    [6083, 486890, 118551, 14814],
    [20229, 401528,  99818, 13478],
    [75180, 343379,  86253, 15182],
    [367114, 354708,  73733, 18934],
    [461468, 244323,  73432, 25418],
    [521792, 189160,  59094, 25222],
    [584240, 205026, 101517, 23003],
    [630775, 214699, 143212, 25820],
    [616066, 180382, 179917, 21488],
]

py_vers = ['Python 3.7', 'Python 3.5', 'Python 2.7', 'others']

d = {
    ver: [month[i] / sum(month) for month in data]
    for i, ver in enumerate(py_vers)
}

months = range(1, 13)
plt.stackplot(months, d.values(), labels=d.keys())
plt.legend(loc='upper left')

# %%
data = [
     [700856, 70169, 22218],
     [612283, 61838, 25987],
     [599908, 60171, 22918],
     [556278, 51744, 18323],
     [470050, 47653, 17354],
     [454124, 43594, 22284],
     [732316, 61417, 20768],
     [720826, 66501, 17366],
     [705028, 68639, 21613],
     [821376, 74655, 17766],
     [911324, 79421, 23824],
     [891456, 82827, 23733],
]

archs = ['armv7l', 'armv6l', 'others']

d = {
    arch: [month[i] / sum(month) for month in data]
    for i, arch in enumerate(archs)
}

months = range(1, 13)
plt.stackplot(months, d.values(), labels=d.keys())
plt.legend(loc='upper left')

# %%
data = [
    [759447,  25208,  8422],
    [665966,  24483,  9522],
    [643848,  31119,  7407],
    [596670,  19546,  9876],
    [506565,  17519, 10378],
    [485744,  17528, 16340],
    [768023,  28354, 16857],
    [754545,  36802, 12777],
    [751616,  26864, 16259],
    [865667,  34231, 13580],
    [962677,  32901, 18520],
    [950068,  30461, 16860],
]

oss = ['Raspbian', 'Debian', 'others']

d = {
    os: [month[i] / sum(month) for month in data]
    for i, os in enumerate(oss)
}

months = range(1, 13)
plt.stackplot(months, d.values(), labels=d.keys())
plt.legend(loc='upper left')

# %%
data = [
    [0, 758678, 424, 244, 33651],
    [0, 665211, 355, 259, 34023],
    [0, 643142, 328, 248, 38539],
    [0, 595092, 385, 1028, 29455],
    [0, 495681, 220, 10461, 27955],
    [33451, 430570, 357, 21246, 33868],
    [324486, 424497, 592, 17805, 45224],
    [448408, 303119, 360, 2299, 49586],
    [507407, 241571, 384, 1866, 43123],
    [601500, 261499, 604, 1740, 47820],
    [677179, 278023, 5156, 1952, 51438],
    [704491, 244044, 228, 876, 47368],
]

distro_versions = ['Raspbian Buster', 'Raspbian Stretch', 'Raspbian Jessie', 'Raspbian (testing)', 'others']

d = {
    dv: [month[i] / sum(month) for month in data]
    for i, dv in enumerate(distro_versions)
}

months = range(1, 13)
plt.stackplot(months, d.values(), labels=d.keys())
plt.legend(loc='upper left')

# %%
plt.rcParams["figure.figsize"] = (15, 6)

downloads = {
    '00:00': 264125,
    '01:00': 264946,
    '02:00': 261761,
    '03:00': 247450,
    '04:00': 242250,
    '05:00': 247956,
    '06:00': 283498,
    '07:00': 332229,
    '08:00': 375837,
    '09:00': 412869,
    '10:00': 425218,
    '11:00': 418954,
    '12:00': 438654,
    '13:00': 473899,
    '14:00': 499082,
    '15:00': 493541,
    '16:00': 482716,
    '17:00': 468915,
    '18:00': 484636,
    '19:00': 492256,
    '20:00': 483939,
    '21:00': 443765,
    '22:00': 373285,
    '23:00': 307041,
}

plt.bar(range(len(downloads)), downloads.values())
plt.title('Downloads throughout the day')
plt.xticks(range(len(downloads)), list(downloads.keys()))

plt.show()
